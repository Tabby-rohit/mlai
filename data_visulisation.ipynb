# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1, 2, 4], [4, 5, 6]) #lineplot
# plt.show()

# %%
# histograms
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
data = np.random.normal(50,10,100)
plt.hist(data,color="skyblue",edgecolor="black",bins=20) #histogram
# plt.show()
# Out:
# (array([ 1.,  0.,  1.,  4.,  3.,  4.,  7.,  6.,  7., 10.,  7., 11., 11.,
#          5.,  6.,  5.,  5.,  2.,  3.,  2.]),
#  array([24.47010184, 26.88147406, 29.29284628, 31.7042185 , 34.11559072,
#         36.52696294, 38.93833516, 41.34970738, 43.7610796 , 46.17245182,
#         48.58382404, 50.99519626, 53.40656848, 55.8179407 , 58.22931292,
#         60.64068514, 63.05205736, 65.46342958, 67.8748018 , 70.28617402,
#         72.69754624]),
#  <BarContainer object of 20 artists>)

# %%
#boxplot
data= [7, 8, 5, 6, 9, 10, 4, 15, 12]
plt.boxplot(data,whis=1.2) #boxplot
# plt.grid(True)
plt.show()

# %%
#stack plot
x = [1, 2, 3, 4, 5,6]
y1 = [2, 3, 4, 2, 6,10]    
y2 = [1, 2, 3, 0, 5,100]
plt.stackplot(x, y1, y2, labels=['y1', 'y2'], colors=['skyblue', 'lightgreen']) #stackplot
plt.legend(loc='upper left')

# %%
plt.subplot(2,1,1) #subplot
plt.plot([1, 2, 3], [4, 5, 6])
plt.subplot(2,2,2)
plt.stackplot(x, y1, y2, labels=['y1', 'y2'], colors=['skyblue', 'lightgreen'])

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax[0,0].plot([1, 2, 3], [4, 5, 6])
ax[0,0].set_title("Line Plot")
ax[0,1].stackplot(x, y1, y2, labels=['y1', 'y2'], colors=['skyblue', 'lightgreen'])
ax[0,1].set_title("Stack Plot")
ax[1,0].hist(data,color="skyblue",edgecolor="black",bins=20)
ax[1,0].set_title("Histogram")
ax[1,1].boxplot(data,whis=1.2)
ax[1,1].set_title("Box Plot")
fig.suptitle("Data Visualization Examples")
plt.tight_layout()

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="smoker",size="size",style="smoker") #scatterplot
plt.title("Scatter Plot of Tips Dataset")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Tips Dataset')

# %%
flt=sns.load_dataset("flights")
flt.head()
sns.lineplot(data=flt,x="year",y="passengers",hue="month") #lineplot
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(flt.pivot(index="month", columns="year", values="passengers"), cmap="coolwarm") #heatmap
# Out:
# <Axes: xlabel='year', ylabel='month'>
